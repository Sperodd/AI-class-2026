# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.model_selection import train_test_split

# %%
# regression: linear regression, decision tree regression, random forest regression

df = pd.read_csv("D:\hanyeowon\Coding\pythonworks\deep\data\diabetes.csv")
df = df.drop("Outcome", axis=1)

y = df["BMI"]
x = df.drop("BMI", axis=1)

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=0)
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\h'
# <>:3: SyntaxWarning: invalid escape sequence '\h'
# C:\Users\gram\AppData\Local\Temp\ipykernel_25740\2619427188.py:3: SyntaxWarning: invalid escape sequence '\h'
#   df = pd.read_csv("D:\hanyeowon\Coding\pythonworks\deep\data\diabetes.csv")

# %%
#linear regression
from sklearn.linear_model import LinearRegression
linear_reg = LinearRegression()

linear_reg.fit(X_train, y_train)
y_pred = linear_reg.predict(X_test)

mse = metrics.mean_squared_error(y_test,y_pred)
print(f"mse = {mse}")

plt.scatter(y_test, y_pred)
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.show()
# Out:
# mse = 52.23558099742443

# %%
# decision tree regression
from sklearn.tree import DecisionTreeRegressor
dt_reg = DecisionTreeRegressor()

dt_reg.fit(X_train, y_train)
y_pred = dt_reg.predict(X_test)

mse = metrics.mean_squared_error(y_test, y_pred)
print(f"mse = {mse}")

plt.scatter(y_test, y_pred)
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.show()
# Out:
# mse = 82.18927083333332

# %%
#random forest regression
from sklearn.ensemble import RandomForestRegressor
rf_reg = RandomForestRegressor()

rf_reg.fit(X_train, y_train)
y_pred = rf_reg.predict(X_test)

mse = metrics.mean_squared_error(y_test, y_pred)
print(f"mse = {mse}")

plt.scatter(y_test, y_pred)
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.show()
# Out:
# mse = 44.918807520833354
