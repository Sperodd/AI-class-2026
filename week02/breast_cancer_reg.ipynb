# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.model_selection import train_test_split

# %%
# regression: linear regression, decision tree regression, random forest regression
df = pd.read_csv("D:\hanyeowon\Coding\pythonworks\deep\data\\breast_cancer.csv")
df = df.drop("label", axis=1)

y = df["worst area"]
x = df.drop("worst area" ,axis=1)

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=0)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\h'
# <>:2: SyntaxWarning: invalid escape sequence '\h'
# C:\Users\gram\AppData\Local\Temp\ipykernel_25304\1943364327.py:2: SyntaxWarning: invalid escape sequence '\h'
#   df = pd.read_csv("D:\hanyeowon\Coding\pythonworks\deep\data\\breast_cancer.csv")

# %%
# linear regression
from sklearn.linear_model import LinearRegression
linear_reg = LinearRegression()

linear_reg.fit(X_train, y_train)
y_pred = linear_reg.predict(X_test)

mse = metrics.mean_squared_error(y_test,y_pred)
print(f"mse = {mse}")

plt.scatter(y_test, y_pred)
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.show()
# Out:
# mse = 1041.179753164841

# %%
# decision tree regression
from sklearn.tree import DecisionTreeRegressor
dt_reg = DecisionTreeRegressor()

dt_reg.fit(X_train, y_train)
y_pred = dt_reg.predict(X_test)

mse = metrics.mean_squared_error(y_test, y_pred)
print(f"mse = {mse}")

plt.scatter(y_test, y_pred)
plt.xlabel("Actual")
plt.ylabel("Predicted")
# Out:
# mse = 2279.2553846153846
# Text(0, 0.5, 'Predicted')

# %%
#random forest regression
from sklearn.ensemble import RandomForestRegressor
rf_reg = RandomForestRegressor()

rf_reg.fit(X_train, y_train)
y_pred = rf_reg.predict(X_test)

mse = metrics.mean_squared_error(y_test, y_pred)
print(f"mse = {mse}")

plt.scatter(y_test, y_pred)
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.show()
# Out:
# mse = 2095.75100486014
